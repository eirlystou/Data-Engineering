# %% [markdown]
# <a href="https://colab.research.google.com/github/eirlystou/Data-Engineering/blob/main/week_12/02_EDA_Consumer_Behavior_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: 내 드라이브를 마운트(mount) 하라

from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# prompt: /content/drive/MyDrive/data/df.pkl 을 읽어줘
import pandas as pd
# %time df = pd.read_pickle('/content/drive/MyDrive/data/mapped_df.pkl')
df
# Out:
# CPU times: user 22.2 ms, sys: 3.15 ms, total: 25.3 ms
# Wall time: 593 ms
#      성별  연령        지역         직업         소득       학력 주거형태          결혼여부  \
# 0     남  14        서울  학생(재수생포함)  500-599만원   중학교 재학   자가            미혼
# 1     남  14        서울  학생(재수생포함)  700-799만원   중학교 재학   자가            미혼
# 2     남  14        서울  학생(재수생포함)  500-599만원   중학교 재학   자가            미혼
# 3     남  14        서울  학생(재수생포함)  700-799만원   중학교 재학   전세            미혼
# 4     남  14        서울  학생(재수생포함)  500-599만원   중학교 재학   자가            미혼
# ...  ..  ..       ...        ...        ...      ...  ...           ...
# 7995  여  58  광주/전라/제주     기능/노무직    99만원 이하   중학교 졸업   자가  기타(이혼/별거/사별)
# 7996  여  63  광주/전라/제주       전업주부  600-699만원  고등학교 졸업   자가            기혼
# 7997  여  61  광주/전라/제주     기능/노무직  300-399만원   중학교 졸업   전세            기혼
# 7998  여  67  광주/전라/제주     기능/노무직  100-199만원   중학교 졸업   자가  기타(이혼/별거/사별)
# 7999  여  65  광주/전라/제주       전업주부  300-399만원  고등학교 졸업   자가            기혼
#
#         자녀수  평일인터넷  ...            국드장르3       국드장르4      국드장르5  국드장르6  \
# 0       NaN  180.0  ...              NaN         NaN        NaN    NaN
# 1       NaN    NaN  ...  웹툰/소설/만화 원작 드라마         NaN        NaN    NaN
# 2       NaN    0.0  ...              NaN         NaN        NaN    NaN
# 3       NaN   90.0  ...           액션 드라마  의학/메디컬 드라마  공포/호러 드라마   퓨전사극
# 4       NaN   60.0  ...              NaN         NaN        NaN    NaN
# ...     ...    ...  ...              ...         ...        ...    ...
# 7995     2명    NaN  ...          스포츠 드라마         NaN        NaN    NaN
# 7996     2명    NaN  ...              NaN         NaN        NaN    NaN
# 7997     1명    NaN  ...           가족 드라마        정통사극        NaN    NaN
# 7998     2명    NaN  ...              NaN         NaN        NaN    NaN
# 7999  3명 이상    NaN  ...              NaN         NaN        NaN    NaN
#
#           국드장르7           국드장르8 국드장르9 국드장르10 PPL구입여부  year
# 0           NaN             NaN   NaN    NaN      있다  2018
# 1           NaN             NaN   NaN    NaN      없다  2018
# 2           NaN             NaN   NaN    NaN      없다  2018
# 3     청춘/학원 드라마  코미디/시트콤/예능 드라마   NaN    NaN      있다  2018
# 4           NaN             NaN   NaN    NaN      없다  2018
# ...         ...             ...   ...    ...     ...   ...
# 7995        NaN             NaN   NaN    NaN      있다  2019
# 7996        NaN             NaN   NaN    NaN      없다  2019
# 7997        NaN             NaN   NaN    NaN      없다  2019
# 7998        NaN             NaN   NaN    NaN      없다  2019
# 7999        NaN             NaN   NaN    NaN      없다  2019
#
# [8000 rows x 39 columns]

# %%
# prompt: /content/drive/MyDrive/data/merged_df.csv 를 읽어다오
# %time merged_df = pd.read_csv('/content/drive/MyDrive/data/merged_df.csv') # [['항목코드_y', '항목코드_x', '항목코드명']]
merged_df
# Out:
# CPU times: user 10.1 ms, sys: 77 µs, total: 10.2 ms
# Wall time: 30.7 ms
#             항목ID  항목코드_x           항목코드명   항목코드_y
# 0          A_001       1               남       성별
# 1          A_001       2               여       성별
# 2          A_004       1              서울       지역
# 3          A_004       2           경기/인천       지역
# 4          A_004       3        대전/충청/세종       지역
# ..           ...     ...             ...      ...
# 486  C_01_003#10      21             복수극   국드장르10
# 487  C_01_003#10      22              기타   국드장르10
# 488  C_01_003#10      23  특별히 즐겨보는 장르 없음   국드장르10
# 489     C_01_033       1              있다  PPL구입여부
# 490     C_01_033       2              없다  PPL구입여부
#
# [491 rows x 4 columns]

# %%
merged_df.columns
# Out:
# Index(['항목ID', '항목코드_x', '항목코드명', '항목코드_y'], dtype='object')

# %%
merged_df[['항목코드_y', '항목코드_x', '항목코드명']]
# Out:
#       항목코드_y  항목코드_x           항목코드명
# 0         성별       1               남
# 1         성별       2               여
# 2         지역       1              서울
# 3         지역       2           경기/인천
# 4         지역       3        대전/충청/세종
# ..       ...     ...             ...
# 486   국드장르10      21             복수극
# 487   국드장르10      22              기타
# 488   국드장르10      23  특별히 즐겨보는 장르 없음
# 489  PPL구입여부       1              있다
# 490  PPL구입여부       2              없다
#
# [491 rows x 3 columns]

# %%
merged_df= merged_df[['항목코드_y', '항목코드_x', '항목코드명']]
merged_df
# Out:
#       항목코드_y  항목코드_x           항목코드명
# 0         성별       1               남
# 1         성별       2               여
# 2         지역       1              서울
# 3         지역       2           경기/인천
# 4         지역       3        대전/충청/세종
# ..       ...     ...             ...
# 486   국드장르10      21             복수극
# 487   국드장르10      22              기타
# 488   국드장르10      23  특별히 즐겨보는 장르 없음
# 489  PPL구입여부       1              있다
# 490  PPL구입여부       2              없다
#
# [491 rows x 3 columns]

# %%
# prompt: merged_df를 nested 사전형으로 만들라. {'성별' : {'1': '남', '2':'여'}, '지역'': {'1':''서울', '2':'경기.인천'} 이런 형태로 만들어다오

# Create an empty dictionary to store the nested dictionary
nested_dict = {}

# Iterate through each column in the DataFrame
for col in merged_df.columns:
  # Create a sub-dictionary for each column
  nested_dict[col] = {}
  # Iterate through each row in the DataFrame for current column
  for index, row in merged_df.iterrows():
    # Add key-value pairs to the sub-dictionary
    nested_dict[col][str(row['항목코드_y'])] = row[col]

# Print the nested dictionary (optional)
nested_dict
# Out:
# {'항목ID': {'성별': 'A_001',
#   '지역': 'A_004',
#   '직업': 'A_006',
#   '소득': 'A_007',
#   '학력': 'A_013',
#   '주거형태': 'A_016',
#   '결혼여부': 'A_019',
#   '자녀수': 'A_027',
#   'TV장르1': 'C_01_001#1',
#   'TV장르2': 'C_01_001#2',
#   'TV장르3': 'C_01_001#3',
#   'TV장르4': 'C_01_001#4',
#   'TV장르5': 'C_01_001#5',
#   'TV장르6': 'C_01_001#6',
#   'TV장르7': 'C_01_001#7',
#   'TV장르8': 'C_01_001#8',
#   'TV장르9': 'C_01_001#9',
#   'TV장르10': 'C_01_001#10',
#   'TV장르11': 'C_01_001#11',
#   'TV장르12': 'C_01_001#12',
#   '국드장르1': 'C_01_003#1',
#   '국드장르2': 'C_01_003#2',
#   '국드장르3': 'C_01_003#3',
#   '국드장르4': 'C_01_003#4',
#   '국드장르5': 'C_01_003#5',
#   '국드장르6': 'C_01_003#6',
#   '국드장르7': 'C_01_003#7',
#   '국드장르8': 'C_01_003#8',
#   '국드장르9': 'C_01_003#9',
#   '국드장르10': 'C_01_003#10',
#   'PPL구입여부': 'C_01_033'},
#  '항목코드_x': {'성별': 2,
#   '지역': 7,
#   '직업': 7,
#   '소득': 99,
#   '학력': 99,
#   '주거형태': 9,
#   '결혼여부': 9,
#   '자녀수': 99,
#   'TV장르1': 17,
#   'TV장르2': 17,
#   'TV장르3': 17,
#   'TV장르4': 17,
#   'TV장르5': 17,
#   'TV장르6': 17,
#   'TV장르7': 17,
#   'TV장르8': 17,
#   'TV장르9': 17,
#   'TV장르10': 17,
#   'TV장르11': 17,
#   'TV장르12': 17,
#   '국드장르1': 23,
#   '국드장르2': 23,
#   '국드장르3': 23,
#   '국드장르4': 23,
#   '국드장르5': 23,
#   '국드장르6': 23,
#   '국드장르7': 23,
#   '국드장르8': 23,
#   '국드장르9': 23,
#   '국드장르10': 23,
#   'PPL구입여부': 2},
#  '항목코드명': {'성별': '여',
#   '지역': '강원',
#   '직업': '무직/기타',
#   '소득': '모름/무응답',
#   '학력': '무응답',
#   '주거형태': '무응답',
#   '결혼여부': '무응답',
#   '자녀수': '무응답',
#   'TV장르1': '기타',
#   'TV장르2': '기타',
#   'TV장르3': '기타',
#   'TV장르4': '기타',
#   'TV장르5': '기타',
#   'TV장르6': '기타',
#   'TV장르7': '기타',
#   'TV장르8': '기타',
#   'TV장르9': '기타',
#   'TV장르10': '기타',
#   'TV장르11': '기타',
#   'TV장르12': '기타',
#   '국드장르1': '특별히 즐겨보는 장르 없음',
#   '국드장르2': '특별히 즐겨보는 장르 없음',
#   '국드장르3': '특별히 즐겨보는 장르 없음',
#   '국드장르4': '특별히 즐겨보는 장르 없음',
#   '국드장르5': '특별히 즐겨보는 장르 없음',
#   '국드장르6': '특별히 즐겨보는 장르 없음',
#   '국드장르7': '특별히 즐겨보는 장르 없음',
#   '국드장르8': '특별히 즐겨보는 장르 없음',
#   '국드장르9': '특별히 즐겨보는 장르 없음',
#   '국드장르10': '특별히 즐겨보는 장르 없음',
#   'PPL구입여부': '없다'},
#  '항목코드_y': {'성별': '성별',
#   '지역': '지역',
#   '직업': '직업',
#   '소득': '소득',
#   '학력': '학력',
#   '주거형태': '주거형태',
#   '결혼여부': '결혼여부',
#   '자녀수': '자녀수',
#   'TV장르1': 'TV장르1',
#   'TV장르2': 'TV장르2',
#   'TV장르3': 'TV장르3',
#   'TV장르4': 'TV장르4',
#   'TV장르5': 'TV장르5',
#   'TV장르6': 'TV장르6',
#   'TV장르7': 'TV장르7',
#   'TV장르8': 'TV장르8',
#   'TV장르9': 'TV장르9',
#   'TV장르10': 'TV장르10',
#   'TV장르11': 'TV장르11',
#   'TV장르12': 'TV장르12',
#   '국드장르1': '국드장르1',
#   '국드장르2': '국드장르2',
#   '국드장르3': '국드장르3',
#   '국드장르4': '국드장르4',
#   '국드장르5': '국드장르5',
#   '국드장르6': '국드장르6',
#   '국드장르7': '국드장르7',
#   '국드장르8': '국드장르8',
#   '국드장르9': '국드장르9',
#   '국드장르10': '국드장르10',
#   'PPL구입여부': 'PPL구입여부'}}

# %% [markdown]
# ### **chatGPT에게 물어보기**

# %%
nested_dict = {}
for _, row in merged_df.iterrows():
    category = row['항목코드_y']
    code = row['항목코드_x']
    name = row['항목코드명']

    if category not in nested_dict:
        nested_dict[category] = {}
    nested_dict[category][code] = name

nested_dict
# Out:
# {'성별': {1: '남', 2: '여'},
#  '지역': {1: '서울',
#   2: '경기/인천',
#   3: '대전/충청/세종',
#   4: '광주/전라/제주',
#   5: '부산/울산/경남',
#   6: '대구/경북',
#   7: '강원'},
#  '직업': {1: '행정관리/전문직',
#   2: '사무직',
#   3: '판매/서비스직',
#   4: '기능/노무직',
#   5: '전업주부',
#   6: '학생(재수생포함)',
#   7: '무직/기타'},
#  '소득': {1: '99만원 이하',
#   2: '100-199만원',
#   3: '200-299만원',
#   4: '300-399만원',
#   5: '400-499만원',
#   6: '500-599만원',
#   7: '600-699만원',
#   8: '700-799만원',
#   9: '800-899만원',
#   10: '900-999만원',
#   11: '1000만원 이상',
#   99: '모름/무응답'},
#  '학력': {1: '정규교육 없음',
#   2: '초등학교 졸업',
#   3: '중학교 졸업',
#   4: '고등학교 졸업',
#   5: '전문대학 졸업',
#   6: '대학교 졸업',
#   7: '대학원 졸업',
#   8: '중학교 재학',
#   9: '고등학교 재학',
#   10: '전문대학 재학',
#   11: '대학교 재학',
#   12: '대학원 재학',
#   99: '무응답'},
#  '주거형태': {1: '자가', 2: '전세', 3: '월세', 4: '영구임대', 5: '사택/기타', 9: '무응답'},
#  '결혼여부': {1: '기혼', 2: '미혼', 3: '기타(이혼/별거/사별)', 9: '무응답'},
#  '자녀수': {1: '1명', 2: '2명', 3: '3명 이상', 99: '무응답'},
#  'TV장르1': {1: '뉴스/보도',
#   2: '교양/생활정보',
#   3: '시사/토론',
#   4: '국내 드라마',
#   5: '해외 드라마',
#   6: '영화',
#   7: '예능/오락',
#   8: '다큐멘터리',
#   9: '음악/공연/오디션',
#   10: '스포츠/골프',
#   11: '어린이/만화',
#   12: '교육',
#   13: '게임',
#   14: '종교',
#   15: '경제정보',
#   16: '취미/레저',
#   17: '기타'},
#  'TV장르2': {1: '뉴스/보도',
#   2: '교양/생활정보',
#   3: '시사/토론',
#   4: '국내 드라마',
#   5: '해외 드라마',
#   6: '영화',
#   7: '예능/오락',
#   8: '다큐멘터리',
#   9: '음악/공연/오디션',
#   10: '스포츠/골프',
#   11: '어린이/만화',
#   12: '교육',
#   13: '게임',
#   14: '종교',
#   15: '경제정보',
#   16: '취미/레저',
#   17: '기타'},
#  'TV장르3': {1: '뉴스/보도',
#   2: '교양/생활정보',
#   3: '시사/토론',
#   4: '국내 드라마',
#   5: '해외 드라마',
#   6: '영화',
#   7: '예능/오락',
#   8: '다큐멘터리',
#   9: '음악/공연/오디션',
#   10: '스포츠/골프',
#   11: '어린이/만화',
#   12: '교육',
#   13: '게임',
#   14: '종교',
#   15: '경제정보',
#   16: '취미/레저',
#   17: '기타'},
#  'TV장르4': {1: '뉴스/보도',
#   2: '교양/생활정보',
#   3: '시사/토론',
#   4: '국내 드라마',
#   5: '해외 드라마',
#   6: '영화',
#   7: '예능/오락',
#   8: '다큐멘터리',
#   9: '음악/공연/오디션',
#   10: '스포츠/골프',
#   11: '어린이/만화',
#   12: '교육',
#   13: '게임',
#   14: '종교',
#   15: '경제정보',
#   16: '취미/레저',
#   17: '기타'},
#  'TV장르5': {1: '뉴스/보도',
#   2: '교양/생활정보',
#   3: '시사/토론',
#   4: '국내 드라마',
#   5: '해외 드라마',
#   6: '영화',
#   7: '예능/오락',
#   8: '다큐멘터리',
#   9: '음악/공연/오디션',
#   10: '스포츠/골프',
#   11: '어린이/만화',
#   12: '교육',
#   13: '게임',
#   14: '종교',
#   15: '경제정보',
#   16: '취미/레저',
#   17: '기타'},
#  'TV장르6': {1: '뉴스/보도',
#   2: '교양/생활정보',
#   3: '시사/토론',
#   4: '국내 드라마',
#   5: '해외 드라마',
#   6: '영화',
#   7: '예능/오락',
#   8: '다큐멘터리',
#   9: '음악/공연/오디션',
#   10: '스포츠/골프',
#   11: '어린이/만화',
#   12: '교육',
#   13: '게임',
#   14: '종교',
#   15: '경제정보',
#   16: '취미/레저',
#   17: '기타'},
#  'TV장르7': {1: '뉴스/보도',
#   2: '교양/생활정보',
#   3: '시사/토론',
#   4: '국내 드라마',
#   5: '해외 드라마',
#   6: '영화',
#   7: '예능/오락',
#   8: '다큐멘터리',
#   9: '음악/공연/오디션',
#   10: '스포츠/골프',
#   11: '어린이/만화',
#   12: '교육',
#   13: '게임',
#   14: '종교',
#   15: '경제정보',
#   16: '취미/레저',
#   17: '기타'},
#  'TV장르8': {1: '뉴스/보도',
#   2: '교양/생활정보',
#   3: '시사/토론',
#   4: '국내 드라마',
#   5: '해외 드라마',
#   6: '영화',
#   7: '예능/오락',
#   8: '다큐멘터리',
#   9: '음악/공연/오디션',
#   10: '스포츠/골프',
#   11: '어린이/만화',
#   12: '교육',
#   13: '게임',
#   14: '종교',
#   15: '경제정보',
#   16: '취미/레저',
#   17: '기타'},
#  'TV장르9': {1: '뉴스/보도',
#   2: '교양/생활정보',
#   3: '시사/토론',
#   4: '국내 드라마',
#   5: '해외 드라마',
#   6: '영화',
#   7: '예능/오락',
#   8: '다큐멘터리',
#   9: '음악/공연/오디션',
#   10: '스포츠/골프',
#   11: '어린이/만화',
#   12: '교육',
#   13: '게임',
#   14: '종교',
#   15: '경제정보',
#   16: '취미/레저',
#   17: '기타'},
#  'TV장르10': {1: '뉴스/보도',
#   2: '교양/생활정보',
#   3: '시사/토론',
#   4: '국내 드라마',
#   5: '해외 드라마',
#   6: '영화',
#   7: '예능/오락',
#   8: '다큐멘터리',
#   9: '음악/공연/오디션',
#   10: '스포츠/골프',
#   11: '어린이/만화',
#   12: '교육',
#   13: '게임',
#   14: '종교',
#   15: '경제정보',
#   16: '취미/레저',
#   17: '기타'},
#  'TV장르11': {1: '뉴스/보도',
#   2: '교양/생활정보',
#   3: '시사/토론',
#   4: '국내 드라마',
#   5: '해외 드라마',
#   6: '영화',
#   7: '예능/오락',
#   8: '다큐멘터리',
#   9: '음악/공연/오디션',
#   10: '스포츠/골프',
#   11: '어린이/만화',
#   12: '교육',
#   13: '게임',
#   14: '종교',
#   15: '경제정보',
#   16: '취미/레저',
#   17: '기타'},
#  'TV장르12': {1: '뉴스/보도',
#   2: '교양/생활정보',
#   3: '시사/토론',
#   4: '국내 드라마',
#   5: '해외 드라마',
#   6: '영화',
#   7: '예능/오락',
#   8: '다큐멘터리',
#   9: '음악/공연/오디션',
#   10: '스포츠/골프',
#   11: '어린이/만화',
#   12: '교육',
#   13: '게임',
#   14: '종교',
#   15: '경제정보',
#   16: '취미/레저',
#   17: '기타'},
#  '국드장르1': {1: '로맨스 드라마',
#   2: '성공신화 드라마',
#   3: '정치 드라마',
#   4: '멜로 드라마',
#   5: '가족 드라마',
#   6: '정통사극',
#   7: '액션 드라마',
#   8: '스포츠 드라마',
#   9: '의학/메디컬 드라마',
#   10: '형사/추리/법정 드라마',
#   11: '공포/호러 드라마',
#   12: '퓨전사극',
#   13: '청춘/학원 드라마',
#   14: '코미디/시트콤/예능 드라마',
#   15: '타임슬립 드라마',
#   16: '리메이크 드라마',
#   17: '웹툰/소설/만화 원작 드라마',
#   18: '시즌/시리즈 드라마',
#   19: '판타지 드라마',
#   20: '휴먼 드라마',
#   21: '복수극',
#   22: '기타',
#   23: '특별히 즐겨보는 장르 없음'},
#  '국드장르2': {1: '로맨스 드라마',
#   2: '성공신화 드라마',
#   3: '정치 드라마',
#   4: '멜로 드라마',
#   5: '가족 드라마',
#   6: '정통사극',
#   7: '액션 드라마',
#   8: '스포츠 드라마',
#   9: '의학/메디컬 드라마',
#   10: '형사/추리/법정 드라마',
#   11: '공포/호러 드라마',
#   12: '퓨전사극',
#   13: '청춘/학원 드라마',
#   14: '코미디/시트콤/예능 드라마',
#   15: '타임슬립 드라마',
#   16: '리메이크 드라마',
#   17: '웹툰/소설/만화 원작 드라마',
#   18: '시즌/시리즈 드라마',
#   19: '판타지 드라마',
#   20: '휴먼 드라마',
#   21: '복수극',
#   22: '기타',
#   23: '특별히 즐겨보는 장르 없음'},
#  '국드장르3': {1: '로맨스 드라마',
#   2: '성공신화 드라마',
#   3: '정치 드라마',
#   4: '멜로 드라마',
#   5: '가족 드라마',
#   6: '정통사극',
#   7: '액션 드라마',
#   8: '스포츠 드라마',
#   9: '의학/메디컬 드라마',
#   10: '형사/추리/법정 드라마',
#   11: '공포/호러 드라마',
#   12: '퓨전사극',
#   13: '청춘/학원 드라마',
#   14: '코미디/시트콤/예능 드라마',
#   15: '타임슬립 드라마',
#   16: '리메이크 드라마',
#   17: '웹툰/소설/만화 원작 드라마',
#   18: '시즌/시리즈 드라마',
#   19: '판타지 드라마',
#   20: '휴먼 드라마',
#   21: '복수극',
#   22: '기타',
#   23: '특별히 즐겨보는 장르 없음'},
#  '국드장르4': {1: '로맨스 드라마',
#   2: '성공신화 드라마',
#   3: '정치 드라마',
#   4: '멜로 드라마',
#   5: '가족 드라마',
#   6: '정통사극',
#   7: '액션 드라마',
#   8: '스포츠 드라마',
#   9: '의학/메디컬 드라마',
#   10: '형사/추리/법정 드라마',
#   11: '공포/호러 드라마',
#   12: '퓨전사극',
#   13: '청춘/학원 드라마',
#   14: '코미디/시트콤/예능 드라마',
#   15: '타임슬립 드라마',
#   16: '리메이크 드라마',
#   17: '웹툰/소설/만화 원작 드라마',
#   18: '시즌/시리즈 드라마',
#   19: '판타지 드라마',
#   20: '휴먼 드라마',
#   21: '복수극',
#   22: '기타',
#   23: '특별히 즐겨보는 장르 없음'},
#  '국드장르5': {1: '로맨스 드라마',
#   2: '성공신화 드라마',
#   3: '정치 드라마',
#   4: '멜로 드라마',
#   5: '가족 드라마',
#   6: '정통사극',
#   7: '액션 드라마',
#   8: '스포츠 드라마',
#   9: '의학/메디컬 드라마',
#   10: '형사/추리/법정 드라마',
#   11: '공포/호러 드라마',
#   12: '퓨전사극',
#   13: '청춘/학원 드라마',
#   14: '코미디/시트콤/예능 드라마',
#   15: '타임슬립 드라마',
#   16: '리메이크 드라마',
#   17: '웹툰/소설/만화 원작 드라마',
#   18: '시즌/시리즈 드라마',
#   19: '판타지 드라마',
#   20: '휴먼 드라마',
#   21: '복수극',
#   22: '기타',
#   23: '특별히 즐겨보는 장르 없음'},
#  '국드장르6': {1: '로맨스 드라마',
#   2: '성공신화 드라마',
#   3: '정치 드라마',
#   4: '멜로 드라마',
#   5: '가족 드라마',
#   6: '정통사극',
#   7: '액션 드라마',
#   8: '스포츠 드라마',
#   9: '의학/메디컬 드라마',
#   10: '형사/추리/법정 드라마',
#   11: '공포/호러 드라마',
#   12: '퓨전사극',
#   13: '청춘/학원 드라마',
#   14: '코미디/시트콤/예능 드라마',
#   15: '타임슬립 드라마',
#   16: '리메이크 드라마',
#   17: '웹툰/소설/만화 원작 드라마',
#   18: '시즌/시리즈 드라마',
#   19: '판타지 드라마',
#   20: '휴먼 드라마',
#   21: '복수극',
#   22: '기타',
#   23: '특별히 즐겨보는 장르 없음'},
#  '국드장르7': {1: '로맨스 드라마',
#   2: '성공신화 드라마',
#   3: '정치 드라마',
#   4: '멜로 드라마',
#   5: '가족 드라마',
#   6: '정통사극',
#   7: '액션 드라마',
#   8: '스포츠 드라마',
#   9: '의학/메디컬 드라마',
#   10: '형사/추리/법정 드라마',
#   11: '공포/호러 드라마',
#   12: '퓨전사극',
#   13: '청춘/학원 드라마',
#   14: '코미디/시트콤/예능 드라마',
#   15: '타임슬립 드라마',
#   16: '리메이크 드라마',
#   17: '웹툰/소설/만화 원작 드라마',
#   18: '시즌/시리즈 드라마',
#   19: '판타지 드라마',
#   20: '휴먼 드라마',
#   21: '복수극',
#   22: '기타',
#   23: '특별히 즐겨보는 장르 없음'},
#  '국드장르8': {1: '로맨스 드라마',
#   2: '성공신화 드라마',
#   3: '정치 드라마',
#   4: '멜로 드라마',
#   5: '가족 드라마',
#   6: '정통사극',
#   7: '액션 드라마',
#   8: '스포츠 드라마',
#   9: '의학/메디컬 드라마',
#   10: '형사/추리/법정 드라마',
#   11: '공포/호러 드라마',
#   12: '퓨전사극',
#   13: '청춘/학원 드라마',
#   14: '코미디/시트콤/예능 드라마',
#   15: '타임슬립 드라마',
#   16: '리메이크 드라마',
#   17: '웹툰/소설/만화 원작 드라마',
#   18: '시즌/시리즈 드라마',
#   19: '판타지 드라마',
#   20: '휴먼 드라마',
#   21: '복수극',
#   22: '기타',
#   23: '특별히 즐겨보는 장르 없음'},
#  '국드장르9': {1: '로맨스 드라마',
#   2: '성공신화 드라마',
#   3: '정치 드라마',
#   4: '멜로 드라마',
#   5: '가족 드라마',
#   6: '정통사극',
#   7: '액션 드라마',
#   8: '스포츠 드라마',
#   9: '의학/메디컬 드라마',
#   10: '형사/추리/법정 드라마',
#   11: '공포/호러 드라마',
#   12: '퓨전사극',
#   13: '청춘/학원 드라마',
#   14: '코미디/시트콤/예능 드라마',
#   15: '타임슬립 드라마',
#   16: '리메이크 드라마',
#   17: '웹툰/소설/만화 원작 드라마',
#   18: '시즌/시리즈 드라마',
#   19: '판타지 드라마',
#   20: '휴먼 드라마',
#   21: '복수극',
#   22: '기타',
#   23: '특별히 즐겨보는 장르 없음'},
#  '국드장르10': {1: '로맨스 드라마',
#   2: '성공신화 드라마',
#   3: '정치 드라마',
#   4: '멜로 드라마',
#   5: '가족 드라마',
#   6: '정통사극',
#   7: '액션 드라마',
#   8: '스포츠 드라마',
#   9: '의학/메디컬 드라마',
#   10: '형사/추리/법정 드라마',
#   11: '공포/호러 드라마',
#   12: '퓨전사극',
#   13: '청춘/학원 드라마',
#   14: '코미디/시트콤/예능 드라마',
#   15: '타임슬립 드라마',
#   16: '리메이크 드라마',
#   17: '웹툰/소설/만화 원작 드라마',
#   18: '시즌/시리즈 드라마',
#   19: '판타지 드라마',
#   20: '휴먼 드라마',
#   21: '복수극',
#   22: '기타',
#   23: '특별히 즐겨보는 장르 없음'},
#  'PPL구입여부': {1: '있다', 2: '없다'}}

# %%
# prompt: df의 컬럼명을 해당되는 nested_dict의 key를 찾아 해당 key의 값을 mapping하여 df의 값을 변경하라

import pandas as pd

def map_column_values(df, nested_dict):
    """
    Maps column values in a DataFrame based on a nested dictionary.

    Args:
        df: The input DataFrame.
        nested_dict: The nested dictionary containing the mapping.

    Returns:
        The DataFrame with mapped column values.
    """

    # Create a copy of the DataFrame to avoid modifying the original
    mapped_df = df.copy()

    for column in df.columns:
        if column in nested_dict:
            # Create a mapping dictionary for the current column
            mapping = nested_dict[column]

            # Use the mapping dictionary to update the column values
            mapped_df[column] = df[column].map(mapping)

    return mapped_df

# Example usage (assuming df and nested_dict are defined)
# Replace 'your_column_name' with the actual column name you want to map
mapped_df = map_column_values(df, nested_dict)
mapped_df
# Out:
#        성별  연령   지역   직업   소득   학력 주거형태 결혼여부  자녀수  평일인터넷  ...  국드장르3  국드장르4  \
# 0     NaN  14  NaN  NaN  NaN  NaN  NaN  NaN  NaN  180.0  ...    NaN    NaN
# 1     NaN  14  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN  ...    NaN    NaN
# 2     NaN  14  NaN  NaN  NaN  NaN  NaN  NaN  NaN    0.0  ...    NaN    NaN
# 3     NaN  14  NaN  NaN  NaN  NaN  NaN  NaN  NaN   90.0  ...    NaN    NaN
# 4     NaN  14  NaN  NaN  NaN  NaN  NaN  NaN  NaN   60.0  ...    NaN    NaN
# ...   ...  ..  ...  ...  ...  ...  ...  ...  ...    ...  ...    ...    ...
# 7995  NaN  58  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN  ...    NaN    NaN
# 7996  NaN  63  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN  ...    NaN    NaN
# 7997  NaN  61  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN  ...    NaN    NaN
# 7998  NaN  67  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN  ...    NaN    NaN
# 7999  NaN  65  NaN  NaN  NaN  NaN  NaN  NaN  NaN    NaN  ...    NaN    NaN
#
#       국드장르5  국드장르6  국드장르7 국드장르8 국드장르9 국드장르10 PPL구입여부  year
# 0       NaN    NaN    NaN   NaN   NaN    NaN     NaN  2018
# 1       NaN    NaN    NaN   NaN   NaN    NaN     NaN  2018
# 2       NaN    NaN    NaN   NaN   NaN    NaN     NaN  2018
# 3       NaN    NaN    NaN   NaN   NaN    NaN     NaN  2018
# 4       NaN    NaN    NaN   NaN   NaN    NaN     NaN  2018
# ...     ...    ...    ...   ...   ...    ...     ...   ...
# 7995    NaN    NaN    NaN   NaN   NaN    NaN     NaN  2019
# 7996    NaN    NaN    NaN   NaN   NaN    NaN     NaN  2019
# 7997    NaN    NaN    NaN   NaN   NaN    NaN     NaN  2019
# 7998    NaN    NaN    NaN   NaN   NaN    NaN     NaN  2019
# 7999    NaN    NaN    NaN   NaN   NaN    NaN     NaN  2019
#
# [8000 rows x 39 columns]

# %%
# prompt: mapped_df를 /content/drive/MyDrive/data에 pickle로 저장하라

import pickle

# Save the mapped_df DataFrame to a pickle file
with open('/content/drive/MyDrive/data/mapped_df.pkl', 'wb') as f:
    pickle.dump(mapped_df, f)
